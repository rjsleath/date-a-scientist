# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("profiles.csv")

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
# ...

# %%
df.describe()
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.340290     68.295281    20033.222534
# std        9.452779      3.994803    97346.192104
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %%
from matplotlib import pyplot as plt
df.age.value_counts()

plt.hist(df.age, bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.xlim(16, 80)
plt.show()

# %%
df.income.value_counts()
# Out:
# -1          48442
#  20000       2952
#  100000      1621
#  80000       1111
#  30000       1048
#  40000       1005
#  50000        975
#  60000        736
#  70000        707
#  150000       631
#  1000000      521
#  250000       149
#  500000        48
# Name: income, dtype: int64

# %%
#-1s look like incorrect data. I'm going to replace them with the average income.

mean_income = df.income.mean(skipna=True)

df['income']=df.income.mask(df.income == -1,mean_income)
df.income.value_counts()
# Out:
# 20033.222534      48442
# 20000.000000       2952
# 100000.000000      1621
# 80000.000000       1111
# 30000.000000       1048
# 40000.000000       1005
# 50000.000000        975
# 60000.000000        736
# 70000.000000        707
# 150000.000000       631
# 1000000.000000      521
# 250000.000000       149
# 500000.000000        48
# Name: income, dtype: int64

# %%
df.age.value_counts()
# Out:
# 26     3724
# 27     3685
# 28     3583
# 25     3531
# 29     3295
# 24     3242
# 30     3149
# 31     2735
# 23     2592
# 32     2587
# 33     2206
# 22     1934
# 34     1902
# 35     1755
# 36     1583
# 37     1427
# 38     1330
# 21     1282
# 39     1172
# 42     1072
# 40     1030
# 41      980
# 20      953
# 43      858
# 44      708
# 45      643
# 19      611
# 46      578
# 47      529
# 48      481
# 49      459
# 50      437
# 51      350
# 52      344
# 18      309
# 56      271
# 54      267
# 55      265
# 57      256
# 53      252
# 59      221
# 58      197
# 60      195
# 61      176
# 62      167
# 63      138
# 64      113
# 65      109
# 66      105
# 67       66
# 68       59
# 69       31
# 110       1
# 109       1
# Name: age, dtype: int64

# %%
df.height.value_counts()
# Out:
# 70.0    6074
# 68.0    5449
# 67.0    5354
# 72.0    5315
# 69.0    5179
# 71.0    4826
# 66.0    4759
# 64.0    3865
# 65.0    3794
# 73.0    2815
# 63.0    2767
# 74.0    2547
# 62.0    2244
# 75.0    1382
# 61.0    1090
# 60.0     791
# 76.0     783
# 77.0     280
# 59.0     212
# 78.0     132
# 79.0      57
# 58.0      53
# 80.0      27
# 95.0      20
# 57.0      17
# 83.0      12
# 36.0      11
# 81.0      11
# 82.0      11
# 84.0       9
# 56.0       8
# 55.0       6
# 53.0       5
# 54.0       3
# 94.0       3
# 91.0       3
# 50.0       2
# 43.0       2
# 37.0       2
# 48.0       2
# 88.0       2
# 8.0        1
# 93.0       1
# 4.0        1
# 49.0       1
# 1.0        1
# 42.0       1
# 86.0       1
# 47.0       1
# 87.0       1
# 90.0       1
# 52.0       1
# 9.0        1
# 51.0       1
# 89.0       1
# 6.0        1
# 3.0        1
# 92.0       1
# 85.0       1
# 26.0       1
# Name: height, dtype: int64

# %%
df.status.value_counts()
# Out:
# single            55697
# seeing someone     2064
# available          1865
# married             310
# unknown              10
# Name: status, dtype: int64

# %%
plt.hist(df.status)
plt.xlabel("Status")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df.sex)
plt.xlabel("Sex")
plt.ylabel("Frequency")
plt.title('Male and Female')
plt.show()

# %%
sex_mapping = {"m": 0, "f": 1}
df["sex_code"] = df.sex.map(sex_mapping)
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
# ...

# %%
plt.hist(df.smokes)
plt.xlabel("Smokes")
plt.ylabel("Frequency")
plt.title('Smokers')
plt.xticks(rotation=60)
plt.show()

# %%
smokes_mapping = {"no": 0, "sometimes": 1, "trying to quit": 2, "when drinking": 3, "yes": 4, "nan": ' '}
df["smokes_code"] = df.smokes.map(smokes_mapping)

# %%
drink_mapping = {"not at all": 0, "rarely": 1, "socially": 2, "often": 3, "very often": 4, "desperately": 5}

df["drinks_code"] = df.drinks.map(drink_mapping)

# %%
plt.hist(df.body_type)
plt.xlabel("Body Type")
plt.ylabel("Frequency")
plt.title('Body Types')
plt.xticks(rotation=60)
plt.show()

# %%
body_mapping = {"nan": 0, "a little extra": 1, "athletic": 2, "average": 3, "curvy": 4, "fit": 5, "full figured": 6, "jacked": 7, "overweight": 8, "rather not say": 9,"skinny": 10, "thin": 11, "used up":12 }

df["body_code"] = df.body_type.map(body_mapping)
df.body_code.head()
# Out:
# 0     1.0
# 1     3.0
# 2    11.0
# 3    11.0
# 4     2.0
# Name: body_code, dtype: float64

# %%
agg = df.groupby(df.body_type).mean()
agg.head(12)
# Out:
#                       age     height         income  sex_code  drinks_code  \
# body_type
# a little extra  34.123621  68.820084   36239.111630  0.312286     1.825799
# athletic        32.049412  69.707336   41226.003245  0.195363     1.890872
# average         32.642097  68.100805   32536.764293  0.383565     1.894901
# curvy           32.055046  65.210245   30325.562721  0.971203     1.911076
# fit             33.530485  68.546062   36362.885475  0.348596     1.910655
# full figured    34.050545  66.464817   39965.065201  0.862240     1.827273
# jacked          29.847981  69.292162  107527.718336  0.306413     2.203562
# overweight      34.988739  68.948198   38962.093287  0.326577     1.687646
# rather not say  32.045455  67.272727   34016.913272  0.535354     1.835165
# skinny          27.771525  68.544176   38011.318445  0.338210     1.954112
# thin            31.598811  67.866058   34402.814880  0.524093     1.914729
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
feature_data = agg[['age', 'height', 'income']]


x = feature_data.values
min_max_scaler = sklearn.preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)


feature_data = pd.DataFrame(x_scaled, columns=feature_data.columns)
feature_data.head(15)
# Out:
#          age    height    income
# 0   0.880131  0.802705  0.074357
# 1   0.592734  1.000000  0.137062
# 2   0.674855  0.642762  0.027804
# 3   0.593514  0.000000  0.000000
# 4   0.797948  0.741772  0.075913
# 5   0.870006  0.278974  0.121207
# 6   0.287709  0.907679  0.970740
# 7   1.000000  0.831194  0.108596
# 8   0.592186  0.458626  0.046415
# 9   0.000000  0.741353  0.096641
# 10  0.530300  0.590563  0.051267
# 11  0.120646  0.882801  1.000000

# %%
feature_data['body_type']  = [ "a little extra", "athletic", "average", "curvy", "fit", "full figured", "jacked", "overweight", "rather not say", "skinny", "thin", "used up" ]
feature_data.head()
# Out:
#         age    height    income       body_type
# 0  0.880131  0.802705  0.074357  a little extra
# 1  0.592734  1.000000  0.137062        athletic
# 2  0.674855  0.642762  0.027804         average
# 3  0.593514  0.000000  0.000000           curvy
# 4  0.797948  0.741772  0.075913             fit

# %%
feature_data.plot.bar('body_type',['age','height', 'income'])
plt.show()
# Out:
# /Users/becky/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
df.replace('', np.nan, inplace=True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
essay_cols = ["essay0","essay1","essay2","essay3","essay4","essay5","essay6","essay7","essay8","essay9"]
all_essays = df[essay_cols].replace(np.nan, '', regex=True)
all_essays = all_essays[essay_cols].apply(lambda x: ' '.join(x), axis=1)
df["essay_len"] = all_essays.apply(lambda x: len(x))
df.essay_len.head()
# Out:
# 0    2644
# 1    1453
# 2    5517
# 3     477
# 4     725
# Name: essay_len, dtype: int64

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
df.replace(np.nan, '0',inplace=True)
normalised_data = df[['age','essay_len', 'body_code', 'income', 'drinks_code', 'smokes_code']].astype(float)


x = normalised_data.values
min_max_scaler = sklearn.preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)


normalised_data = pd.DataFrame(x_scaled, columns=normalised_data.columns)

normalised_data.head(15)
# Out:
#          age  essay_len  body_code    income  drinks_code  smokes_code
# 0   0.043478   0.027372   0.083333  0.000034          0.4         0.25
# 1   0.184783   0.015000   0.250000  0.061224          0.6         0.00
# 2   0.217391   0.057215   0.916667  0.000034          0.4         0.00
# 3   0.054348   0.004861   0.916667  0.000000          0.4         0.00
# 4   0.119565   0.007438   0.166667  0.000034          0.4         0.00
# 5   0.119565   0.025554   0.250000  0.000034          0.4         0.00
# 6   0.152174   0.019820   0.416667  0.000034          0.4         0.00
# 7   0.141304   0.012787   0.250000  0.000034          0.4         0.00
# 8   0.065217   0.023248   0.000000  0.000034          0.4         0.75
# 9   0.206522   0.025045   0.166667  0.000034          0.0         0.00
# 10  0.184783   0.046630   0.250000  0.000034          0.4         1.00
# 11  0.108696   0.047991   0.250000  0.020408          0.4         0.00
# ...

# %%
normalised_data.head()
# Out:
#         age  essay_len  body_code    income  drinks_code  smokes_code
# 0  0.043478   0.027372   0.083333  0.000034          0.4         0.25
# 1  0.184783   0.015000   0.250000  0.061224          0.6         0.00
# 2  0.217391   0.057215   0.916667  0.000034          0.4         0.00
# 3  0.054348   0.004861   0.916667  0.000000          0.4         0.00
# 4  0.119565   0.007438   0.166667  0.000034          0.4         0.00

# %%
#Kmeans
columns = ['age','essay_len', 'income', 'drinks_code', 'smokes_code'] 

X = pd.DataFrame(normalised_data, columns=columns) # load the dataset as a pandas data frame
y = df['body_type'] # define the target variable as y


x_train, x_test, y_train, y_test = train_test_split(X,y,train_size= 0.8, test_size =0.2, random_state=6 )

# %%
classifier = KNeighborsClassifier(n_neighbors = 5)
classifier.fit(x_train, y_train)
guesses = classifier.predict(x_test)

# %%
print(guesses)

# %%
print(classifier.score(x_test, y_test))
# Out:
# 0.2005838198498749

# %%
accuracies=[]
k_list=range(1,101)
for k in range(1, 101):
    classifier = KNeighborsClassifier(n_neighbors = k)
    classifier.fit(x_train, y_train)
    classifier.score(x_test, y_test)
    accuracies.append(classifier.score(x_test, y_test))

# %%
plt.plot(k_list,accuracies)
plt.title("K Value vs Accuracy")
plt.xlabel("K Value")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.plot(k_list,accuracies)
plt.xlim(80,100)
plt.title("K Value vs Accuracy: Upper Range")
plt.xlabel("K Value")
plt.ylabel("Accuracy")
plt.show()

# %%
#SVC 1
classifier= SVC(kernel = 'linear')
classifier.fit(x_train, y_train)
print(classifier.score(x_test, y_test))
# Out:
# 0.060884070058381985

# %%
#SVC 2
classifier= SVC(kernel = 'poly')
classifier.fit(x_train, y_train)
print(classifier.score(x_test, y_test))
# Out:
# 0.06255212677231026

# %%
#SVC 3
classifier= SVC(kernel = 'rbf')
classifier.fit(x_train, y_train)
print(classifier.score(x_test, y_test))
# Out:
# 0.060884070058381985

# %%
#linear regression
X = pd.DataFrame(normalised_data, columns=['essay_len']) # load the dataset as a pandas data frame
y = df['age'] # define the target variable as y

plt.plot(X, y, 'o')
plt.title("Essay Length vs Age")
plt.xlabel("Essay Length")
plt.ylabel("Age")
plt.show()

# %%
line_fitter = LinearRegression()
line_fitter.fit(X, y)
age_predict = line_fitter.predict(X)

plt.plot(X,y,"o")
plt.plot(X, age_predict)
plt.title("Essay Length vs Age")
plt.xlabel("Essay Length")
plt.ylabel("Age")
plt.show()

# %%
print(line_fitter.coef_)
# Out:
# [35.40479166]

# %%
#multilinear regression
columns = ['essay_len','income', 'drinks_code', 'smokes_code'] 

X = pd.DataFrame(normalised_data, columns=columns) # load the dataset as a pandas data frame
y = df['age'] # define the target variable as y


x_train, x_test, y_train, y_test = train_test_split(X,y,train_size= 0.8, test_size =0.2, random_state=6 )

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)
y_predict = mlr.predict(x_test)

# %%
plt.scatter(y_test, y_predict)
plt.xlabel('y_test')
plt.ylabel('y_predict')
plt.title('Age Actual vs Predicted Values')
plt.show()

# %%
print(mlr.coef_)
#The first column (essay_len) has the biggest coefficient by far, so it has the strongest effect on age. It's positive, so older people write longer essays.
# Out:
# [34.51630073  0.69836243 -4.13724573 -4.74553587]

# %%
print("Train score:")
print(mlr.score(x_train, y_train))

print("Test score:")
print(mlr.score(x_test, y_test))

#Accuracy:  these variables only explain about 2-3% of the variation in age.
# Out:
# Train score:
# 0.03031744166663075
# Test score:
# 0.02253634791299386
